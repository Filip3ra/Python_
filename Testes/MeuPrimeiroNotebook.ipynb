# %% [markdown]
# #Conteúdo aqui é só texto, atalho pra isso é clicar na célula + M

# %% [raw]
# Tipo RAW o que colocar aqui não passa por tratamento

# %%
#Tipo código, aqui é executado com tratamento
